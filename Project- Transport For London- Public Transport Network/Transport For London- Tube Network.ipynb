# %% [markdown]
# # Project- Transport For London- Tube Network
# Select a city with extensive public transport network. (Here I have used Transport for London Network). By utilising the Python programming language, represent part of the public transport network (e.g., bus, tube…) of the selected city by using the graph data structure.
#
# The implementation of the transport network is expected to consist of minimum 5 lines as edges, and minimum 5 stations on each line as nodes.
#
# The network should be completely interconnected, ensuring that there are edges connecting every pair of nodes.
#
# When visualising the network, use different colours for the different lines and their corresponding stations.
#
# Set up and display attributes for the edges, which represent the distances between the stations. If precise station-to-station distances are unavailable, estimate them by leveraging online mapping services such as Google Maps.
#
# Visualise the names of the lines and the stations on the generated map.
#
# Reference: Transport for London Tube Map - https://th.bing.com/th/id/R.2096ecaf00c5a107ad8d212c8655949d?rik=X0ZPFT3UXbiHcQ&riu=http%3a%2f%2fwww.projectmapping.co.uk%2fReviews%2fResources%2fTube+map+Dec+2019.jpg&ehk=paIpAXD58AF7GkpRvLH8Tvf%2f5m1V%2fIBB5GZkmcZIY7w%3d&risl=&pid=ImgRaw&r=0

# %%
import matplotlib.pyplot as plt
import networkx as nx
import warnings
warnings.filterwarnings("ignore")

MyGraph = nx.Graph()

# Central Line
MyGraph.add_node('White City', npos=(0, 0), ccn='#FF0000')
MyGraph.add_node('Shepherd Bush', npos=(1, 0), ccn='#FF0000')
MyGraph.add_node('Holland Park', npos=(2, 0), ccn='#FF0000')
MyGraph.add_node('Notting Hill Gate', npos=(3, 0), ccn='#FF0000')##Common station with Circle Line
MyGraph.add_node('Queensway', npos=(4, 0), ccn='#FF0000')
MyGraph.add_node('Lancaster Gate', npos=(5, 0), ccn='#FF0000')
MyGraph.add_node('Marble Arch', npos=(6, 0), ccn='#FF0000')
MyGraph.add_node('Bond Street', npos=(7, 0), ccn='#FF0000')##Common station with Jubilee Line
MyGraph.add_node('Oxford Circus', npos=(8, 0), ccn='#FF0000')##Common station with Victoria Line
MyGraph.add_node('Tottenham Court', npos=(9, 0), ccn='#FF0000')
MyGraph.add_node('Holborn', npos=(10, 0), ccn='#FF0000')##Common station with Picadilly Line

# Jubilee Line
MyGraph.add_node('Swiss Cottage', npos=(7, 3), ccn='#CCCCCC')
MyGraph.add_node('St. John\'s Wood', npos=(7, 2), ccn='#CCCCCC')
MyGraph.add_node('Baker Street', npos=(7, 1), ccn='#CCCCCC')
MyGraph.add_node('Bond Street', npos=(7, 0), ccn='#CCCCCC') ##Common station with Central Line
MyGraph.add_node('Green Park', npos=(7, -1), ccn='#CCCCCC')##Common station with Piccadilly Line
MyGraph.add_node('Westminster', npos=(7, -2), ccn='#CCCCCC') ##Common station with  Circle Line
MyGraph.add_node('Waterloo', npos=(7, -3), ccn='#CCCCCC')
MyGraph.add_node('Southwark', npos=(7, -4), ccn='#CCCCCC')
MyGraph.add_node('London Bridge', npos=(7, -5), ccn='#CCCCCC')

#Circle Line
MyGraph.add_node('Edgware Road', npos=(3,3), ccn='#FFFF00')
MyGraph.add_node('Paddington', npos=(3,2), ccn='#FFFF00')
MyGraph.add_node('Bayswater', npos=(3, 1), ccn='#FFFF00')
MyGraph.add_node('Notting Hill Gate', npos=(3, 0), ccn='#FFFF00')## Common Station with Central Line
MyGraph.add_node('High Street Kensington', npos=(3, -1), ccn='#FFFF00')
MyGraph.add_node('Gloucester Road', npos=(3, -2), ccn='#FFFF00')
MyGraph.add_node('South Kensington', npos=(3, -3), ccn='#FFFF00')##Common station with Piccadilly Line
MyGraph.add_node('Sloane Square', npos=(4, -2), ccn='#FFFF00')
MyGraph.add_node('Victoria', npos=(5, -2), ccn='#FFFF00')##Common station with Victoria Line
MyGraph.add_node('St. Jame\'s Park', npos=(6, -2), ccn='#FFFF00')
MyGraph.add_node('Westminster', npos=(7, -2), ccn='#FFFF00') ##Common station with Jubilee Line
MyGraph.add_node('Embankment', npos=(8, -2), ccn='#FFFF00')

## Victoria Line
MyGraph.add_node('King\'s Cross St. Pancras', npos=(9, 3), ccn='#7DF9FF')##Common station with Picadilly Line
MyGraph.add_node('Euston', npos=(9, 2), ccn='#7DF9FF')
MyGraph.add_node('Warran Street', npos=(9, 1), ccn='#7DF9FF')
MyGraph.add_node('Oxford Circus', npos=(8, 0), ccn='#7DF9FF') ##Common station with Central Line
MyGraph.add_node('Green Park', npos=(7, -1), ccn='#7DF9FF') ##Common station with Jubilee Line and Piccadilly Line
MyGraph.add_node('Victoria', npos=(5, -2), ccn='#7DF9FF') ##Common station with  Circle Line
MyGraph.add_node('Pimlico', npos=(5, -3), ccn='#7DF9FF')
MyGraph.add_node('Vauxhall', npos=(5, -4), ccn='#7DF9FF')
MyGraph.add_node('Stockwell', npos=(5, -5), ccn='#7DF9FF')
MyGraph.add_node('Brixton', npos=(5, -6), ccn='#7DF9FF')

# Piccadilly Line
MyGraph.add_node('King\'s Cross St. Pancras', npos=(9, 3), ccn='#90EE90') ##Common station with Victoria Line
MyGraph.add_node('Russel Square', npos=(10, 1.5), ccn='#90EE90')
MyGraph.add_node('Holborn', npos=(10, 0), ccn='#90EE90') ##Common station with Central Line
MyGraph.add_node('Covent Garden', npos=(10, -1), ccn='#90EE90')
MyGraph.add_node('Leicester Square', npos=(9, -1), ccn='#90EE90')
MyGraph.add_node('Piccadilly Circus', npos=(8, -1), ccn='#90EE90')
MyGraph.add_node('Green Park', npos=(7,-1), ccn='#90EE90') ##Common station with Jubilee Line and Victoria Line
MyGraph.add_node('Hyde Park Corner', npos=(5.5,-1), ccn='#90EE90')
MyGraph.add_node('Knightbridge', npos=(4.25, -1), ccn='#90EE90')
MyGraph.add_node('South Kensington', npos=(3,-3), ccn='#90EE90')##Common station with Circle Line


#Connect all edges in Central line
MyGraph.add_edge('White City', 'Shepherd Bush', cce='#FF0000', distance = 1.16)
MyGraph.add_edge('Shepherd Bush', 'Holland Park', cce='#FF0000', distance = 0.87)
MyGraph.add_edge('Holland Park', 'Notting Hill Gate', cce='#FF0000', distance = 0.61)
MyGraph.add_edge('Notting Hill Gate', 'Queensway', cce='#FF0000', distance = 0.69)
MyGraph.add_edge('Queensway','Lancaster Gate', cce='#FF0000', distance = 0.90)
MyGraph.add_edge('Lancaster Gate', 'Marble Arch', cce='#FF0000', distance = 1.20)
MyGraph.add_edge('Marble Arch', 'Bond Street', cce='#FF0000', distance = 0.55)
MyGraph.add_edge('Bond Street', 'Oxford Circus', cce='#FF0000', distance = 0.66)
MyGraph.add_edge('Oxford Circus', 'Tottenham Court', cce='#FF0000', distance = 0.58)
MyGraph.add_edge('Tottenham Court','Holborn', cce='#FF0000', distance = 0.88)

# Connect all edges in Jubilee Line
MyGraph.add_edge('Swiss Cottage', 'St. John\'s Wood', cce='#CCCCCC', distance = 0.92)
MyGraph.add_edge('St. John\'s Wood', 'Baker Street', cce='#CCCCCC', distance = 2.06)
MyGraph.add_edge('Baker Street', 'Bond Street', cce='#CCCCCC', distance = 1.66)
MyGraph.add_edge('Bond Street', 'Green Park', cce='#CCCCCC', distance = 1.37)
MyGraph.add_edge('Green Park','Westminster', cce='#CCCCCC', distance = 1.34)
MyGraph.add_edge('Westminster', 'Waterloo', cce='#CCCCCC', distance = 0.96)
MyGraph.add_edge('Waterloo','Southwark', cce='#CCCCCC', distance = 0.44)
MyGraph.add_edge('Southwark', 'London Bridge', cce='#CCCCCC', distance = 1.26)



#Connect all edges in Circle line
MyGraph.add_edge('Edgware Road', 'Paddington', cce='#FFFF00', distance = 0.82)
MyGraph.add_edge('Paddington', 'Bayswater', cce='#FFFF00', distance = 0.98)
MyGraph.add_edge('Bayswater', 'Notting Hill Gate', cce='#FFFF00', distance = 0.79)
MyGraph.add_edge('Notting Hill Gate', 'High Street Kensington', cce='#FFFF00', distance = 0.93)
MyGraph.add_edge('High Street Kensington','Gloucester Road', cce='#FFFF00', distance = 1.1)
MyGraph.add_edge('Gloucester Road', 'South Kensington', cce='#FFFF00', distance =0.74 )
MyGraph.add_edge('South Kensington', 'Sloane Square', cce='#FFFF00', distance = 1.22)
MyGraph.add_edge('Sloane Square', 'Victoria', cce='#FFFF00', distance = 1.05)
MyGraph.add_edge('Victoria', 'St. Jame\'s Park', cce='#FFFF00', distance = 0.72)
MyGraph.add_edge('St. Jame\'s Park','Westminster', cce='#FFFF00', distance = 0.76)
MyGraph.add_edge('Westminster','Embankment', cce='#FFFF00', distance = 0.69)

#Connect all edges in Victoria Line
MyGraph.add_edge('King\'s Cross St. Pancras', 'Euston', cce='#7DF9FF', distance =0.7)
MyGraph.add_edge('Euston', 'Warran Street', cce='#7DF9FF', distance =0.9)
MyGraph.add_edge('Warran Street', 'Oxford Circus', cce='#7DF9FF', distance = 0.8)
MyGraph.add_edge('Oxford Circus', 'Green Park', cce='#7DF9FF', distance = 1.1)
MyGraph.add_edge('Green Park','Victoria', cce='#7DF9FF', distance = 0.8)
MyGraph.add_edge('Victoria', 'Pimlico', cce='#7DF9FF', distance = 0.9)
MyGraph.add_edge('Pimlico', 'Vauxhall', cce='#7DF9FF', distance = 1.1)
MyGraph.add_edge('Vauxhall', 'Stockwell', cce='#7DF9FF', distance = 0.9)
MyGraph.add_edge('Stockwell','Brixton', cce='#7DF9FF', distance = 0.9)

#Connect all edges in Piccadilly Line
MyGraph.add_edge('King\'s Cross St. Pancras', 'Russel Square', cce='#90EE90', distance = 0.91)
MyGraph.add_edge('Russel Square', 'Holborn', cce='#90EE90', distance = 0.72)
MyGraph.add_edge('Holborn', 'Covent Garden', cce='#90EE90', distance = 0.59)
MyGraph.add_edge('Covent Garden','Leicester Square', cce='#90EE90', distance = 0.25)
MyGraph.add_edge('Leicester Square', 'Piccadilly Circus', cce='#90EE90', distance = 0.49)
MyGraph.add_edge('Piccadilly Circus','Green Park', cce='#90EE90', distance = 0.56)
MyGraph.add_edge('Green Park', 'Hyde Park Corner', cce='#90EE90', distance = 1.06)
MyGraph.add_edge('Hyde Park Corner','Knightbridge', cce='#90EE90', distance = 0.51)
MyGraph.add_edge('Knightbridge', 'South Kensington', cce='#90EE90', distance = 1.22)


# Combine the main plot and the legend
plt.figure(figsize=(20, 20))

# Extract attributes from the graph to dictionaries
pos = nx.get_node_attributes(MyGraph, 'npos')
node_color = nx.get_node_attributes(MyGraph, 'ccn').values()
edge_color = nx.get_edge_attributes(MyGraph, 'cce').values()

# Draw the networkx graph with adjusted node and edge colors
nx.draw_networkx_nodes(MyGraph, pos, node_color=node_color, node_size=1500)
nx.draw_networkx_edges(MyGraph, pos, edge_color=edge_color, width=4)
labels = nx.get_edge_attributes(MyGraph, 'distance')
nx.draw_networkx_edge_labels(MyGraph, pos, edge_labels=labels)

# Draw node names above the nodes
for node, (x, y) in pos.items():
    plt.text(x, y + 0.2, node, fontsize=10, ha='center', va='center')


# Create custom legend labels and colors
legend_labels = ['Central line', 'Jubilee Line', 'Circle Line', 'Victoria Line', 'Piccadilly Line']
legend_colors = ['#FF0000', '#CCCCCC', '#FFFF00', '#7DF9FF', '#90EE90']

# Create a legend with custom elements
for label, color in zip(legend_labels, legend_colors):
    plt.scatter([], [], color=color, label=label)

# Add the legend inside the main plot
plt.legend(title='Tube Transport', loc='upper right', frameon=False, fontsize=10)

# Set the plot title
plt.title('Transport For London Tube Map')

# Display the graph
plt.show()
